# %% [markdown]
# ## Ejercicio - Fundamentos

# %%
my_imput = eval(input("Ingresa tu número telefónico: "))
print(my_imput)
print(type(my_imput))
# Out:
# Ingresa un número: 123456
# 123456
# <class 'int'>

# %%
my_float = eval(input("Ingresa tu calificación"))
print(my_float)
print(type(my_float))
# Out:
# Ingresa un número98.53
# 98.53
# <class 'float'>

# %%
my_string = input("Ingresa tu código postal: ")
print(my_string)
print(type(my_string))
# Out:
# Ingresa un número: 123455
# 123455
# <class 'str'>
