# %%
import requests 

print("Lista de Reproducción\n") 

# Referencia: https://www.deezer.com/en/channels/explore 

print("Ingresa la palabra que te gustaría") 
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock") 

word_to_search = input() 

url = "https://deezerdevs-deezer.p.rapidapi.com/search" 
querystring = {"q":word_to_search} 
headers = {    
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",    
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com" 
} 
response = requests.request("GET", url, headers=headers, params=querystring).json() 

my_list = [] 
for element in response['data']:   
    my_list.append([element['title'], element['artist']['name']]) 
    my_dict = {"Artista": element['artist']
               "Cancion":element['title']}
    
print(my_list)
print(my_dict)
# Out:
#   Cell In[8], line 23
#     my_dict = {"Artista": element['artist']
#                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import requests 

print("Lista de Reproducción\n") 

# Referencia: https://www.deezer.com/en/channels/explore 

print("Ingresa la palabra que te gustaría") 
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock") 

word_to_search = input() 

url = "https://deezerdevs-deezer.p.rapidapi.com/search" 
querystring = {"q":word_to_search} 
headers = {    
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",    
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com" 
} 
response = requests.request("GET", url, headers=headers, params=querystring).json() 

my_list = [] 
for element in response['data']:   
    my_dict = {"Artista": element['artist']['name'],
               "Cancion":element['title']}
    my_list.append(my_dict) 
    
print(my_list)
print("Comprehension: ")

# elements = [element for element in my_list]
for element in my_list:
    print(element)
# print("Comprehension: ")
# print(elements)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría
# Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock
# perro
# [{'Artista': 'Bad Bunny', 'Cancion': 'PERRO NEGRO'}, {'Artista': 'Shakira', 'Cancion': 'Perro Fiel (feat. Nicky Jam)'}, {'Artista': 'Cartel De Santa', 'Cancion': 'Perros'}, {'Artista': 'Perro Callejero', 'Cancion': 'Yo Quiero Ser'}, {'Artista': 'Nicki Nicole', 'Cancion': 'PERROS&GATA$'}, {'Artista': 'Daddy Yankee', 'Cancion': 'Perros Salvajes'}, {'Artista': 'Ivan Cornejo', 'Cancion': 'Perro Abandonado'}, {'Artista': 'Romeo Santos', 'Cancion': 'Perro'}, {'Artista': 'La Maquinaria Norteña', 'Cancion': 'Perro Amor'}, {'Artista': 'Ivan Cornejo', 'Cancion': 'Perro Abandonado (Deluxe)'}, {'Artista': 'Molotov', 'Cancion': 'Perro Negro Granjero (Perro Negro Y Callejero Y La Grange)'}, {'Artista': 'Gallina Pintadita', 'Cancion': 'Perro Amigo'}, {'Artista': 'Daddy Yankee', 'Cancion': 'Perros Salvajes'}, {'Artista': 'Three Souls in My Mind', 'Cancion': 'Perro negro y callejero'}, {'Artista': 'Perro Callejero', 'Cancion': 'Me Quedo'}, {'Artista': 'Seru Giran', 'Cancion': 'Perro Andaluz'}, {'Artista': 'Perro Callejero', 'Cancion': 'Lo Dulce y Lo Prohibido'}, {'Artista': 'Shakira', 'Cancion': 'Perro Fiel/El Perdón Medley (feat. Nicky Jam) (El Dorado World Tour Live)'}, {'Artista': 'Perrozompopo', 'Cancion': 'Entre Remolinos'}, {'Artista': 'LOS INQUIETOS DEL NORTE', 'Cancion': 'Perro Desgraciado'}, {'Artista': 'Chima Chiodi', 'Cancion': 'Perro Salchicha'}, {'Artista': 'Diego Daza', 'Cancion': 'Perro Con Perro'}, {'Artista': 'Alemán', 'Cancion': 'Perro Callejero'}, {'Artista': 'Perro Callejero', 'Cancion': 'Yo Quiero Ser'}, {'Artista': 'Diomedes Diaz', 'Cancion': 'Perro Sinverguenza'}]
# Comprehension:
# {'Artista': 'Bad Bunny', 'Cancion': 'PERRO NEGRO'}
# {'Artista': 'Shakira', 'Cancion': 'Perro Fiel (feat. Nicky Jam)'}
# {'Artista': 'Cartel De Santa', 'Cancion': 'Perros'}
# {'Artista': 'Perro Callejero', 'Cancion': 'Yo Quiero Ser'}
# {'Artista': 'Nicki Nicole', 'Cancion': 'PERROS&GATA$'}
# {'Artista': 'Daddy Yankee', 'Cancion': 'Perros Salvajes'}
# {'Artista': 'Ivan Cornejo', 'Cancion': 'Perro Abandonado'}
# {'Artista': 'Romeo Santos', 'Cancion': 'Perro'}
# {'Artista': 'La Maquinaria Norteña', 'Cancion': 'Perro Amor'}
# {'Artista': 'Ivan Cornejo', 'Cancion': 'Perro Abandonado (Deluxe)'}
# {'Artista': 'Molotov', 'Cancion': 'Perro Negro Granjero (Perro Negro Y Callejero Y La Grange)'}
# {'Artista': 'Gallina Pintadita', 'Cancion': 'Perro Amigo'}
# {'Artista': 'Daddy Yankee', 'Cancion': 'Perros Salvajes'}
# {'Artista': 'Three Souls in My Mind', 'Cancion': 'Perro negro y callejero'}
# {'Artista': 'Perro Callejero', 'Cancion': 'Me Quedo'}
# {'Artista': 'Seru Giran', 'Cancion': 'Perro Andaluz'}
# {'Artista': 'Perro Callejero', 'Cancion': 'Lo Dulce y Lo Prohibido'}
# {'Artista': 'Shakira', 'Cancion': 'Perro Fiel/El Perdón Medley (feat. Nicky Jam) (El Dorado World Tour Live)'}
# {'Artista': 'Perrozompopo', 'Cancion': 'Entre Remolinos'}
# {'Artista': 'LOS INQUIETOS DEL NORTE', 'Cancion': 'Perro Desgraciado'}
# {'Artista': 'Chima Chiodi', 'Cancion': 'Perro Salchicha'}
# {'Artista': 'Diego Daza', 'Cancion': 'Perro Con Perro'}
# {'Artista': 'Alemán', 'Cancion': 'Perro Callejero'}
# {'Artista': 'Perro Callejero', 'Cancion': 'Yo Quiero Ser'}
# {'Artista': 'Diomedes Diaz', 'Cancion': 'Perro Sinverguenza'}
