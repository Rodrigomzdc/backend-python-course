# %%
import requests 

print("Lista de Reproducción\n") 

# Referencia: https://www.deezer.com/en/channels/explore 

print("Ingresa la palabra que te gustaría") 
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock") 

word_to_search = input() 

url = "https://deezerdevs-deezer.p.rapidapi.com/search" 
querystring = {"q":word_to_search} 
headers = {    
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",    
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com" 
} 

response = requests.request("GET", url, headers=headers, params=querystring).json() 
for element in response['data']:    
    my_list = [element['title'], element['artist']['name']]
    my_tupla = tuple(my_list)
    print(my_tupla)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría
# Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock
# Austin tv
# ["Austin (Boots Stop Workin')", 'Dasha']
# ['Ella No Me Conoce', 'Austin tv']
# ['Marduk', 'Austin tv']
# ['Reflejo Infinito', 'Austin tv']
# ['Shiva', 'Austin tv']
# ['Todo Final Es También un Comienzo', 'Austin tv']
# ['Su Nombre Es el Tuyo', 'Austin tv']
# ['Rucci', 'Austin tv']
# ['De la Orquídea y la Avispa', 'Austin tv']
# ['Ana No Te Fallé. B', 'Austin tv']
# ['Lattice', 'Austin tv']
# ['Roy Rogers', 'Austin tv']
# ['Olvidé Decir Adiós', 'Austin tv']
# ['Satélite', 'Austin tv']
# ['Lo Bonito de la Muerte', 'Austin tv']
# ['Máquinas Abstractas', 'Austin tv']
# ['Ésta Es la Razón', 'Austin tv']
# ['Hazme Sentir', 'Austin tv']
# ['Hasta las Hifas, un Micelio', 'Austin tv']
# ['De la Orquídea y la Avispa', 'Austin tv']
# ['Esa Soy Yo', 'Austin tv']
# ['El Secreto (De Las Luciérnagas)', 'Austin tv']
# ['Les Choses Sont Bizarres', 'Austin tv']
# ['Flores Sobre Las Piedras', 'Austin tv']
# ['Voces Iluminadas Por Sonrientes', 'Austin tv']
