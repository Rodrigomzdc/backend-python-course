# %%
def home(request):
    context = {
        "debug": settings.DEBUG,
        "django_ver": get_version() + "TEST CHANGES",
        "python_ver": os.environ["PYTHON_VERSION"] + "MORE TEST",
    }
    return render(request, "pages/home.html", context)
