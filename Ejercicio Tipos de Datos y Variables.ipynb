# %%
def suma(a,b):
    my_local_variable= a + b 
    print("El resultado de la suma es: ", my_local_variable)
def resta(a,b):
    my_local_variable= a - b
    print("El resultado de la resta es: ", my_local_variable)
def multiplicacion(a,b):
    my_local_variable= a * b
    print("El resultado de la multiplicacon es: ", my_local_variable)
def division(a,b):
    my_local_variable= a / b
    print("El resultado de la division es: ", my_local_variable)
def potencia(a,b):
    my_local_variable= a**b
    print("El resultado de la potencia es: ", my_local_variable)
    
número_1 = int(input("Inrgesa tu primer número: " ))
número_2 = int(input("Inrgesa tu segundo número: " ))
suma(número_1,número_2)

número_1 = int(input("Inrgesa tu primer número: " ))
número_2 = int(input("Inrgesa tu segundo número: " ))
resta(número_1,número_2)

número_1 = int(input("Inrgesa tu primer número: " ))
número_2 = int(input("Inrgesa tu segundo número: " ))
multiplicacion(número_1,número_2)

número_1 = int(input("Inrgesa tu primer número: " ))
número_2 = int(input("Inrgesa tu segundo número: " ))
division(número_1,número_2)

número_1 = int(input("Inrgesa tu primer número: " ))
número_2 = int(input("Inrgesa tu segundo número: " ))
potencia(número_1,número_2)
# Out:
# Inrgesa tu primer número: 1
# Inrgesa tu segundo número: 1
# El resultado de la suma es:  2
# Inrgesa tu primer número: 2
# Inrgesa tu segundo número: 1
# El resultado de la resta es:  1
# Inrgesa tu primer número: 2
# Inrgesa tu segundo número: 2
# El resultado de la multiplicacon es:  4
# Inrgesa tu primer número: 6
# Inrgesa tu segundo número: 2
# El resultado de la division es:  3.0
# Inrgesa tu primer número: 2
# Inrgesa tu segundo número: 3
# El resultado de la potencia es:  8
